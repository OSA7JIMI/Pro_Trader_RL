# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from environment import BuyKnowledge

# %%
n_envs = 4
lr = 0.0001
n_steps = 2048
batch_size = 64
ent_coef = 0.01
vf_coef = 0.5
n_epochs = 300

# %%
vec_env = make_vec_env(BuyKnowledge, n_envs = n_envs)
model = PPO("MlpPolicy", vec_env, learning_rate = lr, 
            n_steps = n_steps, batch_size = batch_size, 
            ent_coef = ent_coef, vf_coef = vf_coef, 
            verbose=1)
# Out:
# # of steps: 52164
# # of steps: 52164
# # of steps: 52164
# # of steps: 52164
# Using cpu device

# %%
model = model.learn(total_timesteps=n_steps*n_envs*n_epochs*5)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 2879 |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 8192 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1217         |
# |    iterations           | 2            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0034357742 |
# |    clip_fraction        | 0.00739      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | -0.00138     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.81         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00073     |
# |    std                  | 0.994        |
# ...

# %%
model = model.learn(total_timesteps=n_steps*n_envs*n_epochs*5)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 2805 |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 8192 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1334         |
# |    iterations           | 2            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0069304663 |
# |    clip_fraction        | 0.0937       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -5.14        |
# |    explained_variance   | 0.0356       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.47         |
# |    n_updates            | 15010        |
# |    policy_gradient_loss | 0.00106      |
# |    std                  | 6.7          |
# ...

# %%
model = model.learn(total_timesteps=n_steps*n_envs*n_epochs*5)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 3029 |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 8192 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1338        |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007260942 |
# |    clip_fraction        | 0.0835      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.34       |
# |    explained_variance   | -0.0135     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.86        |
# |    n_updates            | 30010       |
# |    policy_gradient_loss | -0.00205    |
# |    std                  | 93.4        |
# ...

# %%
model.save('buy_knowledge_agent')
