# %%
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from environment import SellKnowledge

# %%
n_envs = 4
lr = 0.0001
n_steps = 2048
batch_size = 64
ent_coef = 0.01
vf_coef = 0.5
n_epochs = 5000

# %%
vec_env = make_vec_env(SellKnowledge, n_envs = n_envs)
model = PPO("MlpPolicy", vec_env, learning_rate = lr, n_steps = n_steps, batch_size = batch_size, ent_coef = ent_coef, vf_coef = vf_coef, verbose=1)
# Out:
# Maximum reward: 365637.02707149443
# # of steps: 379580
# Maximum reward: 365637.02707149443
# # of steps: 379580
# Maximum reward: 365637.0270714945
# # of steps: 379580
# Maximum reward: 365637.02707149443
# # of steps: 379580
# Using cpu device

# %%
model = model.learn(total_timesteps=n_steps*n_envs*n_epochs)
# Out:
# -----------------------------
# | time/              |      |
# |    fps             | 1710 |
# |    iterations      | 1    |
# |    time_elapsed    | 4    |
# |    total_timesteps | 8192 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 754          |
# |    iterations           | 2            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0108133685 |
# |    clip_fraction        | 0.0971       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.85        |
# |    explained_variance   | -0.0148      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.7          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0129      |
# |    std                  | 1.01         |
# ...

# %%
model.save('sell_knowledge_agent')
